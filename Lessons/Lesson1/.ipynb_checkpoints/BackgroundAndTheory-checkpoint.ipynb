# %% [markdown]
# # [Cool Kids Coding School](http://www.coolkidscodingschool.com)
# ## Course: _Beginner Python_
# ### Lesson 1: _Background and Theory_
# ---

# %% [markdown]
# **Overview**
# + Welcome!
# + A little computer history
# + What is inside a computer
# + What are programs?
# + Describe class
# + Demonstration
#
# **What is a computer?**
#
# Everyone "knows" what a computer is, but do you know what is inside a computer?  What it was originally designed to do?  A computer is an electronic machine that processes information: it takes in raw information (or data) at one end, stores it until it's ready to work on it, chews and crunches it for a bit, then spits out the results at the other end. All these processes have a name. Taking in information is called input, storing information is better known as memory (or storage), chewing information is also known as processing, and spitting out results is called output.
#
# **A little history about the computer**
#
# Computers have come a long way.  The electronic computer traces its origin to the 1950's.  At that time only the government, or large corporations could afford them.  They used to be the size of rooms and require a number of technicians and operators to keep them up and running.  The early use was primarily solving math problems, which computers - when programmed for it - can do very well.  This computer below was one of the first supercomputers!  It was called the ENIAC (Electronic Numerical Integrator and Computer).  The computer as we know it, didn't really exist until the 1980's.  Only then did it become cheap enough that people could afford it in their own home.
#
# ![eniac](images/eniac.gif)
#
# Programs that ran these computers used to be printed on cards like the one below, thousands of these cards would be read into memory and that would be the program the computer ran.
#
# ![punch cards](images/ibmCard.png)
#
# The output of the program was printed to paper.
# These early computers used vacuum tubes, al electronic component, that got very hot and needed alot of cooling.
#
# ![vacuum tubes](images/vactubes.gif)
#
# Computers did not start shrinking until vacuum tubes were replaced by the transistor.  The transistor did the same thing that the vacuum tube did but was easier to manage.  We'll talk about what transistors do in a little.
#
# ![transistors](images/transis.gif)
#
# Soon transistors got even smaller.  They got so small that you could fit thousands of them on the size of a quarter.
#
# ![cpu](images/cpu.jpeg)
#
# We went from the computers shown above to the ones you have on your desk.  They became more powerful too, the Eniac could do 5000 calculations per second.  Todays desktops can do about 3 billion!
#
# **What are the main parts of a computer?**
#
# Hardware and software - A computer is composed to two different kinds of components.  The **hardware** is the physical pieces that create the machine.  These are:
# + input
# > keyboard, mouse, any other device that captures information from the real world and turns it into a computer input
# + output
# > monitor, speakers, printer
# + storage
# > hard drive, usb drive, external drive
# + memory
# > computers internal memory that is used to store information and programs that the computer is currently working on, this is also described as RAM
# + cpu
# > the computers "brain", this is the component that coordinates the actions of the other components, as well as executes program instructions
#
# The **software** part is all the programs that run on top of this hardware.  This includes the operating system that is responsible for controlling the different parts of hardware and all the programs that run on top of the operating system.
#
# **What are programs and programming languages?**
#
# Simply a computer program is a set of instructions that describe a task to a computer.  We load this program into the computers memory and then it is executed by the computer.  The output that is generated is dependent on the program.
#
# ```python
#         print('Hello World!')
# ```
#
# This code snippet above can be considered a complete program.  It doesn't do much, but it is valid.  The computer does not understand what is written above. It needs to be traslated to something that the computer knows how to manipulate. The program above eventually gets traslated to this:
#
# > 01110000 01110010 01101001 01101110 01110100 00101000 00100111 01001000 01100101 01101100 01101100
# > 01101111 00100000 01010111 01101111 01110010 01101100 01100100 00100001 00100111 00101001
#
# This is what computers understand.  This is called binary and only two characters are allowed 1 and 0.  Each character is called a bit.  A group of 8 bits is called a byte.  As you can see it's not the most convenient thing for humans to communicate it.  This is why we created programming languages.  It is easier for humans to give instructions to computers this way.  The programming language eventually gets converted to binary and is executed by the computer.
#
# Bytes are related to data size on a computer.  The different measures are:
#
# Unit	Value	Size
# + bit (b)	0 or 1	1/8 of a byte
# + byte (B)	8 bits	1 byte
# + kilobyte (KB)	1,000 bytes
# + megabyte (MB)	1,000,000 bytes
# + gigabyte (GB)	1,000,000,000 bytes
# + terabyte (TB)	1,000,000,000,000 bytes
# + petabyte (PB)	1,000,000,000,000,000 bytes
# + exabyte (EB)	1,000,000,000,000,000,000 bytes
# + zettabyte (ZB)	1,000,000,000,000,000,000,000 bytes
# + yottabyte (YB)	1,000,000,000,000,000,000,000,000 bytes
#
# Here is a graphic that shows how much data space it takes to store various things:
#
#
# ![data size](images/datasize.png)
#
# There are many programming languages available.
#
# ![data size](images/languages.png)
#
# Different languages exist because they are all trying to express a set of instructions to a computer in the most efficient way possible.  Anything you can do in one language you can probably do in another, but how you do it, how much effort it takes to do it.  That is what the differentiator is.  It's like human languages, you can say the same thing in many different languages.  They all look different, but in the end they are trying to achieve the same thing. They are trying to give the computer instructions on how to do a task.
#
# ```python
#     # Python
#     print('Hello World!')
# ```
#
# ```c++
#     // C++
#     std::cout << "Hello World!" << std::endl;
# ```
#
# ```java
#     // java
#     System.out.println("Hello, World");
# ```
#
# ```C#
#     // C#
#     Console.WriteLine("Hello World!");
# ```
#
# These are all languages used in the real world.  Scratch is not used in the real world.  We are going to learn how to program in Python.
#
# |Rank|	Language|	Share|	Trend|
# |----|----------|--------|-------|
# |1|		Python|	24.21 %|	+5.7 %|
# |2|		Java|	22.27 %|	-0.7 %|
# |3|		Javascript|	8.45 %|	+0.1 %|
# |4|		PHP|	7.88 %|	-1.5 %|
# |5|		C#|	7.74 %|	-0.4 %|
# |6|		C/C++|	6.19 %|	-0.8 %|
# |7|		R|	4.15 %|	-0.1 %|
# |8|		Objective-C|	3.33 %|	-1.0 %|
# |9|		Swift|	2.64 %|	-0.9 %|
# |10|		Matlab|	2.08 %|	-0.4 %|
#
# Python as you can see, is one of the most popular programming languages today.  Every year it increases its share a litle bit.  Part of the reason is that Python has been described as a language where "batteries are included".  There are many libraries (shared code) that already do what you are most likely trying to do.  Python was created by Guido Von Rossum in the mid-1980's.
#
# ![data size](images/guido.jpg)
#
# At the end of the course if you've enjoyed using the language he created you can tell him at: ***guido@python.org***
#
# **What are some of the things that a computer program can do?**
#
# You name it, anwhere there is a computer there is a program.
#
# **How big and complicated do programs get?**
#
# The complexity of a piece of software can be measured in two ways.  The first is in the complexity of the design.  Many times that is hard to identify just by looking at a program.  Another more common way is by the number of lines of code.  Here are some examples of different programs and how many lines of code those programs are made of.
#
# ![source lines of code](images/sloc.png)
#
# **How does a computer use a program?**
#
# So once a program is completed and ready what does a computer do with it?  Very simply a program is loaded into memory and the computer executes each line in order until the program completes.  Below is one such program, lets trace it.
#
# Here is a simple program to calculate your age
# ```python
# # this is an example python program to calculate your age
# import datetime
#
# # ask the user what year he/she was born
# print('What year were you born?')
# birth_year = int(input())
#
# # figure out what year it is today
# today_year = datetime.date.today().year
#
# # do the math
# age = today_year - birth_year
#
# # print the result
# print('You are {0} years old this year!'.format(age))
# ```
#
# Here is the output
# > What year were you born?
#
# > 1967
#
# > You are 51 years old this year!
#
# **What are we going to learn in this course?**
#
# We are going to learn how to program using the Python programming language.
# We are also going to learn how to structure and create programs.  Writing programs is not simple it requires you to organize your thoughts and express the steps you have to take to achieve a goal or solve a problem one step at a time.   We are going to learn to create programs, of increasing complexity, that can solve real problems.
#
# You might ask why we are learning python instead of a different language....
#
# > ***Python is a modern, general-purpose, high-level programming language.***
#
# ***General characteristics of Python:***
# + clean and simple language: Easy-to-read and intuitive code, easy-to-learn minimalistic syntax,maintainability scales well with size of projects.
# + expressive language: Fewer lines of code, fewer bugs, easier to maintain.
#
# ***Advantages:***
# + The main advantage is ease of programming, minimizing the time required to develop, debug and maintain the code.
# + Well designed language that encourage many good programming practices:
# + Modular and object-oriented programming, good system for packaging and re-use of code. This often results in more transparent, maintainable and bug-free code.
# + Documentation tightly integrated with the code.
# + A large standard library, and a large collection of add-on packages.
#
# **How is knowing this going to help me?**
#
# There are many reasons why knowing how to program will help you:
# + Here is an important one
#
# > ![top jobs](images/top10payingjobs.png)
#
# + Another reason is, like I explained above, knowing how to program will allow you to organize your thoughts and solve problems step by step methodically.  This process is called creating an **algorithm** that you create and then apply to a problem.
#
# + Another reason is because the world is becoming much more technical.  Computers are everywhere and people that know how use computers to solve problems that have not been solved yet, will be in demand.
#
# + Finally, we are learning how to program, because it's fun!
#
# **How is this course going to be structured?**
#
# ***Instruction***
# > We will discuss new topics in a lesson.
#
# ***In class exercises***
# > I will demonstrate and you will practice the different things we learn.
#
# ***Homework***
# > Every class there will be a homework assigned.  The homework will be due at the next lesson.  It's very important to do the homework.  Like learning a language, if you dont practice you will not learn it.
#
# ***Review***
# > In the 2nd to last class we will refresh the key concepts we have to know.  We will also design our final project.
#
# ***Final class project***
# > We will work together to create our final project.  I will cotribute any code that may be above the level of this class and you will complete it.
#
# **Discuss how to get help**
#
# + Ask questions if you don't understand
# + Built in help system
# + Ask in class
# + Email instructor: <jimmy@coolkidscodingschool.com>
# + Ask after class
#
# **Who is ready to learn Python?**
#
# ![happy](images/happy.gif)
#
# **Demonstrations**
#
# + Demonstrate JupyterHub
# + Demonstrate Jupyter Notebook
# + Demonstrate interesting notebooks
#
# ## Any Questions?
# ---
# ###### for any questions contact <jimmy@coolkidscodingschool.com>
